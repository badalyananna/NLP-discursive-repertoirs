# %%
import pandas as pd

df = pd.read_csv("RepML_original\data\processed\clean\hyperion.csv", sep=',')
df.head(20)
# Out:
#                                               Domanda  \
# 0   A cosa serve questo testo per il perseguimento...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                                 Testo  \
# 0   Dunque vediamo se ho capito: Conte le canta a ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6   #Conte è un pericolo per la libertà e la democ...
# 7   Comunque, se tutti i giornalisti che oggi si s...
# 8                                                 NaN
# 9                                                 NaN
# 10  "Ha suscitato scandalo la proposta di Salvini ...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                                              Stralcio  \
# 0                        Dunque vediamo se ho capito:
# 1              Conte le canta a Salvini e alla Meloni
# 2   questi reagiscono e le cantano a loro volta a ...
# 3   Mentana si smarca da Conte e finisce con foto ...
# 4         Siamo tornati per un attimo alla normalità:
# 5                                meraviglia assoluta!
# 6   #Conte è un pericolo per la libertà e la democ...
# 7                                           Comunque,
# 8   se tutti i giornalisti che oggi si stracciano ...
# 9                forse oggi starebbero più tranquilli
# 10  Ha suscitato scandalo la proposta di Salvini d...
# 11  Non altrettanto scandalo aveva suscitato l’ide...
# 12  Il leader della Lega mescola certo con troppa ...
# 13   E le esigenze di distanziamento sociale rendo...
# 14   Ma le reazioni che ha ricevuto fanno riflettere.
# 15                                 , quasi sdegnate,
# 16  La paradossale verità è che oggi cultura e ind...
# 17  Il processo di secolarizzazione ha ormai espun...
# 18          , anche nel Paese più cattolico d’Europa,
# 19  , come se fosse un sentimento privato, rispett...
#
#                   Repertorio
# 0   dichiarazione di intenti
# 1                    sancire
# 2            giustificazione
# 3                    sancire
# 4                   commento
# 5                   giudizio
# 6               non risposta
# 7                   commento
# 8                valutazione
# 9                possibilità
# 10                   sancire
# 11               valutazione
# 12                  conferma
# 13                  conferma
# 14              implicazione
# 15                  giudizio
# 16                  giudizio
# 17                   sancire
# 18            specificazione
# 19                  commento

# %%
text = []
repertoirs = []
reps = 0
for index, row in df.iterrows():
    if not (pd.isna(row['Testo'])):
        if reps != 0:
            repertoirs.append(reps)
        text.append(row['Testo'])
        reps = []
    if row['Stralcio'] in text[-1]:
        reps.append(row['Repertorio'])
repertoirs.append(reps)

# %%
df1 = pd.DataFrame({'text': text, 'repertoirs': repertoirs})
df1.head()
# Out:
#                                                 text  \
# 0  Dunque vediamo se ho capito: Conte le canta a ...
# 1  #Conte è un pericolo per la libertà e la democ...
# 2  Comunque, se tutti i giornalisti che oggi si s...
# 3  "Ha suscitato scandalo la proposta di Salvini ...
# 4  Non era mai successo nella lunga storia del Pi...
#
#                                           repertoirs
# 0  [dichiarazione di intenti, sancire, giustifica...
# 1                                     [non risposta]
# 2                            [commento, possibilità]
# 3  [sancire, valutazione, conferma, conferma, giu...
# 4  [sancire, specificazione, conferma, causa, cau...

# %%
df1['textlen'] = df1.text.apply(lambda x: len(x.split()))

# %%
df1 = df1[df1.textlen <= 512]

# %%
df1.textlen.hist()
# Out:
# <AxesSubplot:>

# %%
df1['num_rep'] = df1.repertoirs.apply(lambda x: len(x))
df1[df1.num_rep < 10].num_rep.hist(bins=20)

# %%
df1 = df1[df1.num_rep != 0]

# %%
len(df1)
# Out:
# 14770

# %%
max(df1.num_rep)
# Out:
# 41

# %%
df1[df1.num_rep == 41]
# Out:
#                                                    text  \
# 2395  Zaia in diretta oggi: «Covid, si abbassa l'età...
#
#                                              repertoirs  textlen  num_rep
# 2395  [descrizione, sancire, descrizione, contrappos...      467       41

# %%
df1[df1.text == df1[df1.num_rep == 41].text[2395]]
# Out:
#                                                    text  \
# 2395  Zaia in diretta oggi: «Covid, si abbassa l'età...
#
#                                              repertoirs  textlen  num_rep
# 2395  [descrizione, sancire, descrizione, contrappos...      467       41

# %%
df[df.Testo == df1[df1.num_rep == 41].text[2395]]
# Out:
#      Domanda                                              Testo  \
# 7181     NaN  Zaia in diretta oggi: «Covid, si abbassa l'età...
#
#                    Stralcio   Repertorio
# 7181  Zaia in diretta oggi:  descrizione

# %%
df.iloc[7181:7231]
# Out:
#      Domanda                                              Testo  \
# 7181     NaN  Zaia in diretta oggi: «Covid, si abbassa l'età...
# 7182     NaN                                                NaN
# 7183     NaN                                                NaN
# 7184     NaN                                                NaN
# 7185     NaN                                                NaN
# 7186     NaN                                                NaN
# 7187     NaN                                                NaN
# 7188     NaN                                                NaN
# 7189     NaN                                                NaN
# 7190     NaN                                                NaN
# 7191     NaN                                                NaN
# 7192     NaN                                                NaN
# 7193     NaN                                                NaN
# 7194     NaN                                                NaN
# 7195     NaN                                                NaN
# 7196     NaN                                                NaN
# 7197     NaN                                                NaN
# 7198     NaN                                                NaN
# 7199     NaN                                                NaN
# 7200     NaN                                                NaN
# 7201     NaN                                                NaN
# 7202     NaN                                                NaN
# 7203     NaN                                                NaN
# 7204     NaN                                                NaN
# 7205     NaN                                                NaN
# 7206     NaN                                                NaN
# 7207     NaN                                                NaN
# 7208     NaN                                                NaN
# 7209     NaN                                                NaN
# 7210     NaN                                                NaN
# 7211     NaN                                                NaN
# 7212     NaN                                                NaN
# 7213     NaN                                                NaN
# 7214     NaN                                                NaN
# 7215     NaN                                                NaN
# 7216     NaN                                                NaN
# 7217     NaN                                                NaN
# 7218     NaN                                                NaN
# 7219     NaN                                                NaN
# 7220     NaN                                                NaN
# 7221     NaN                                                NaN
# 7222     NaN                                                NaN
# 7223     NaN                                                NaN
# 7224     NaN                                                NaN
# 7225     NaN                                                NaN
# 7226     NaN                                                NaN
# 7227     NaN                                                NaN
# 7228     NaN                                                NaN
# 7229     NaN  Covid Veneto, Zaia attacca il Governo sul Dpcm...
# 7230     NaN                                                NaN
#
#                                                Stralcio  \
# 7181                              Zaia in diretta oggi:
# 7182  «Covid, si abbassa l'età dei positivi, i giova...
# 7183                       Oggi incontro con il Governo
# 7184             ma in Veneto non pensiamo al lockdown»
# 7185  Stiamo parlando, ad esempio, di De Luca in Cam...
# 7186  Il governatore del Veneto invece ha sempre avu...
# 7187          ma votato all'evitare la chiusura totale,
# 7188  come ha ribadito oggi durante la diretta, nume...
# 7189  Soltanto ieri Zaia aveva annunciato di essersi...
# 7190  mettere un bel cartello davanti ai microfoni c...
# 7191                         "indossate la mascherina".
# 7192          «Oggi avremo un confronto con il Governo.
# 7193  Non abbiamo ben capito se per discutere nuove ...
# 7194               - ha annunciato il presidente Zaia -
# 7195  Noi non stiamo meditando lockdown o altre misu...
# 7196                        che riteniamo fondamentale,
# 7197    ma aspettiamo di capire cosa voglia fare Roma.
# 7198  L'ordinanza che abbiamo preparato non è nulla ...
# 7199  Le curve sono inclinate verso l'ascesa e non l...
# 7200  il problema del Covid c'è, noi non siamo negaz...
# 7201  ma presenteremo al Governo la nostra lettura d...
# 7202  Noi non possiamo adottare misure meno restritt...
# 7203    se non con la firma del ministro della Salute:
# 7204                     questo prevede l'ultimo Dpcm».
# 7205  «Non si può morire di virus per tenere tutto a...
# 7206  ma non si può morire di fame per combattere il...
# 7207                         - ha puntualizzato Zaia -.
# 7208  Scelte di natura sanitaria e di natura economi...
# 7209  Il bollettino di oggi Oltre 2 milioni e 200mil...
# 7210  (su 15005 in totale, ossia il 97% dei positivi...
# 7211                              I giovani si ammalano
# 7212                                «Due considerazioni
# 7213       ha precisato ancora il governatore Luca Zaia
# 7214  i positivi sono in maggioranza asintomatici, v...
# 7215  i giovani si stanno ammalando, siamo passati d...
# 7216       Abbiamo giovani con un'alta carica di virus,
# 7217             ma se guardiamo il dato epidemiologico
# 7218                                  nonostante questo
# 7219  l'alta carica non si traduce in positivi sinto...
# 7220                       Ma questo dato va osservato,
# 7221                      potrebbe smentirsi in futuro,
# 7222   questo virus si comporta in modo imprevedibile».
# 7223  Il presidente del Veneto, Luca Zaia, si dice p...
# 7224  perché «nessuno fa un analisi di raffronto tra...
# 7225  «Forse è una questione di pigrizia» a non fare...
# 7226  ipotizza Zaia il quale sottolinea che in Venet...
# 7227  Il 21 ottobre si sono registrati 1.553 positiv...
# 7228  Ciò significa che oggi abbiamo la metà dei pos...
# 7229    Covid Veneto, Zaia attacca il Governo sul Dpcm:
# 7230      «Con queste misure i contagi non scenderanno»
#
#                     Repertorio
# 7181               descrizione
# 7182                   sancire
# 7183               descrizione
# 7184          contrapposizione
# 7185            specificazione
# 7186                  giudizio
# 7187          contrapposizione
# 7188               descrizione
# 7189               descrizione
# 7190               descrizione
# 7191              prescrizione
# 7192  dichiarazione di intenti
# 7193                  commento
# 7194               descrizione
# 7195                   sancire
# 7196                  opinione
# 7197          contrapposizione
# 7198                   sancire
# 7199               descrizione
# 7200                   sancire
# 7201          contrapposizione
# 7202                   sancire
# 7203         ridimensionamento
# 7204                   sancire
# 7205              prescrizione
# 7206          contrapposizione
# 7207               descrizione
# 7208                   sancire
# 7209               descrizione
# 7210            specificazione
# 7211                   sancire
# 7212               descrizione
# 7213               descrizione
# 7214               descrizione
# 7215               valutazione
# 7216                   sancire
# 7217          contrapposizione
# 7218         ridimensionamento
# 7219                   sancire
# 7220          contrapposizione
# 7221               possibilità
# 7222                   sancire
# 7223               descrizione
# 7224           giustificazione
# 7225           giustificazione
# 7226               descrizione
# 7227               descrizione
# 7228                   sancire
# 7229                   sancire
# 7230                previsione

# %%
dup = df1[df1['text'].duplicated(keep=False)].sort_values(by=['text'])
dup
# Out:
#                                                    text  \
# 5415  4 su 10 test rapidi sbagliano completamente l ...
# 5396  4 su 10 test rapidi sbagliano completamente l ...
# 5729  @zaiapresidente Finora aveva dato prova di cap...
# 5711  @zaiapresidente Finora aveva dato prova di cap...
# 7612  A ieri, bollettino del sito Ministero della sa...
# ...                                                 ...
# 3091  È un buona cosa, ma io non ci conterei più di ...
# 5002  È un po’ tardi per lanciare questo messaggio d...
# 5121  È un po’ tardi per lanciare questo messaggio d...
# 6181  È una disordinanza ....un idiozia “innovativa”...
# 6230  È una disordinanza ....un idiozia “innovativa”...
#
#                                              repertoirs  textlen  num_rep
# 5415                                      [valutazione]       39        1
# 5396              [valutazione, deresponsabilizzazione]       39        2
# 5729  [giudizio, conferma, specificazione, prescrizi...       32        5
# 5711         [giudizio, contrapposizione, prescrizione]       32        3
# 7612                                         [commento]       47        1
# ...                                                 ...      ...      ...
# 3091           [contrapposizione, possibilità, sancire]       43        3
# 5002                            [valutazione, giudizio]       43        2
# 5121                                          [sancire]       43        1
# 6181                                         [commento]       37        1
# 6230                                [commento, sancire]       37        2
#
# [163 rows x 4 columns]

# %%
dup['repertoirs_str'] = dup.repertoirs.apply(lambda x: ' '.join(x))

# %%
m1 = ~dup.duplicated(['text', 'repertoirs_str'], keep=False)
m2 = dup.duplicated(['text'], keep=False)
dup[m1 & m2]
# Out:
#                                                    text  \
# 5415  4 su 10 test rapidi sbagliano completamente l ...
# 5396  4 su 10 test rapidi sbagliano completamente l ...
# 5729  @zaiapresidente Finora aveva dato prova di cap...
# 5711  @zaiapresidente Finora aveva dato prova di cap...
# 7361  Adesso io mi chiedo test rapidi, molecolari, s...
# ...                                                 ...
# 3091  È un buona cosa, ma io non ci conterei più di ...
# 5002  È un po’ tardi per lanciare questo messaggio d...
# 5121  È un po’ tardi per lanciare questo messaggio d...
# 6181  È una disordinanza ....un idiozia “innovativa”...
# 6230  È una disordinanza ....un idiozia “innovativa”...
#
#                                              repertoirs  num_rep  textlen  \
# 5415                                      [valutazione]        1       39
# 5396              [valutazione, deresponsabilizzazione]        2       39
# 5729  [giudizio, conferma, specificazione, prescrizi...        5       32
# 5711         [giudizio, contrapposizione, prescrizione]        3       32
# 7361                                 [generalizzazione]        1       92
# ...                                                 ...      ...      ...
# 3091           [contrapposizione, possibilità, sancire]        3       43
# 5002                            [valutazione, giudizio]        2       43
# 5121                                          [sancire]        1       43
# 6181                                         [commento]        1       37
# 6230                                [commento, sancire]        2       37
#
#                                          repertoirs_str
# 5415                                        valutazione
# 5396                 valutazione deresponsabilizzazione
# 5729  giudizio conferma specificazione prescrizione ...
# 5711             giudizio contrapposizione prescrizione
# 7361                                   generalizzazione
# ...                                                 ...
# 3091               contrapposizione possibilità sancire
# 5002                               valutazione giudizio
# 5121                                            sancire
# 6181                                           commento
# 6230                                   commento sancire
#
# [119 rows x 5 columns]

# %%
labels = {
    'anticipazione': [],
    'causa': [],
    'commento': [],
    'conferma': [],
    'considerazione': [],
    'contrapposizione': [],
    'deresponsabilizzazione': [],
    'descrizione': [],
    'dichiarazione di intenti': [],
    'generalizzazione': [],
    'giudizio': [],
    'giustificazione': [],
    'implicazione': [],
    'non risposta': [],
    'opinione': [],
    'possibilità': [],
    'prescrizione': [],
    'previsione': [],
    'proposta': [],
    'ridimensionamento': [],
    'sancire': [],
    'specificazione': [],
    'valutazione': []
}

for index, row in df1.iterrows():
    for key in labels:
        if key in row['repertoirs']:
            labels[key].append(1)
        else:
            labels[key].append(0)

# %%
for key in labels:
    df1[key] = labels[key]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pd.set_option('max_columns', None)
df1.describe()
# Out:
#             textlen       num_rep  anticipazione         causa      commento  \
# count  14770.000000  14770.000000   14770.000000  14770.000000  14770.000000
# mean      56.735477      1.967163       0.002031      0.025254      0.265267
# std       79.521976      1.919412       0.045024      0.156901      0.441490
# min        1.000000      1.000000       0.000000      0.000000      0.000000
# 25%       21.000000      1.000000       0.000000      0.000000      0.000000
# 50%       31.000000      1.000000       0.000000      0.000000      0.000000
# 75%       48.000000      2.000000       0.000000      0.000000      1.000000
# max      512.000000     41.000000       1.000000      1.000000      1.000000
#
#            conferma  considerazione  contrapposizione  deresponsabilizzazione  \
# count  14770.000000    14770.000000      14770.000000            14770.000000
# mean       0.034191        0.014895          0.079282                0.038659
# std        0.181725        0.121137          0.270188                0.192789
# min        0.000000        0.000000          0.000000                0.000000
# 25%        0.000000        0.000000          0.000000                0.000000
# 50%        0.000000        0.000000          0.000000                0.000000
# 75%        0.000000        0.000000          0.000000                0.000000
# max        1.000000        1.000000          1.000000                1.000000
#
#         descrizione  dichiarazione di intenti  generalizzazione      giudizio  \
# count  14770.000000              14770.000000      14770.000000  14770.000000
# mean       0.192620                  0.026540          0.061070      0.145972
# std        0.394371                  0.160741          0.239466      0.353090
# min        0.000000                  0.000000          0.000000      0.000000
# 25%        0.000000                  0.000000          0.000000      0.000000
# 50%        0.000000                  0.000000          0.000000      0.000000
# 75%        0.000000                  0.000000          0.000000      0.000000
# max        1.000000                  1.000000          1.000000      1.000000
#
#        giustificazione  implicazione  non risposta      opinione  \
# count     14770.000000  14770.000000  14770.000000  14770.000000
# mean          0.024915      0.035003      0.067299      0.070684
# std           0.155873      0.183795      0.250547      0.256305
# min           0.000000      0.000000      0.000000      0.000000
# 25%           0.000000      0.000000      0.000000      0.000000
# 50%           0.000000      0.000000      0.000000      0.000000
# 75%           0.000000      0.000000      0.000000      0.000000
# max           1.000000      1.000000      1.000000      1.000000
#
#         possibilità  prescrizione    previsione      proposta  \
# count  14770.000000  14770.000000  14770.000000  14770.000000
# mean       0.028775      0.105552      0.055518      0.013676
# std        0.167178      0.307274      0.228996      0.116147
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000
#
#        ridimensionamento       sancire  specificazione   valutazione
# count       14770.000000  14770.000000    14770.000000  14770.000000
# mean            0.046107      0.278131        0.058158      0.104739
# std             0.209724      0.448094        0.234051      0.306228
# min             0.000000      0.000000        0.000000      0.000000
# 25%             0.000000      0.000000        0.000000      0.000000
# 50%             0.000000      0.000000        0.000000      0.000000
# 75%             0.000000      1.000000        0.000000      0.000000
# max             1.000000      1.000000        1.000000      1.000000

# %%
df2 = df1.drop(['repertoirs'], axis=1)

# %%
df2.sum()
# Out:
# text                        Dunque vediamo se ho capito: Conte le canta a ...
# textlen                                                                837983
# num_rep                                                                 29055
# anticipazione                                                              30
# causa                                                                     373
# commento                                                                 3918
# conferma                                                                  505
# considerazione                                                            220
# contrapposizione                                                         1171
# deresponsabilizzazione                                                    571
# descrizione                                                              2845
# dichiarazione di intenti                                                  392
# generalizzazione                                                          902
# giudizio                                                                 2156
# giustificazione                                                           368
# implicazione                                                              517
# non risposta                                                              994
# opinione                                                                 1044
# possibilità                                                               425
# prescrizione                                                             1559
# previsione                                                                820
# proposta                                                                  202
# ridimensionamento                                                         681
# sancire                                                                  4108
# specificazione                                                            859
# valutazione                                                              1547
# dtype: object

# %%
test_val = df2.sample(frac=0.30, random_state=100)
train = pd.concat([df2,test_val]).drop_duplicates(keep=False)

# %%
test = test_val.sample(frac=0.50, random_state=102)
val = pd.concat([test_val,test]).drop_duplicates(keep=False)

# %%
val.sum()
# Out:
# text                        Per favore, mettete qualche controllo in più n...
# textlen                                                                119991
# num_rep                                                                  4302
# anticipazione                                                               5
# causa                                                                      64
# commento                                                                  583
# conferma                                                                   65
# considerazione                                                             35
# contrapposizione                                                          171
# deresponsabilizzazione                                                     83
# descrizione                                                               431
# dichiarazione di intenti                                                   53
# generalizzazione                                                          150
# giudizio                                                                  335
# giustificazione                                                            58
# implicazione                                                               77
# non risposta                                                              139
# opinione                                                                  161
# possibilità                                                                49
# prescrizione                                                              223
# previsione                                                                112
# proposta                                                                   32
# ridimensionamento                                                         117
# sancire                                                                   621
# specificazione                                                            132
# valutazione                                                               235
# dtype: object

# %%
test.sum()
# Out:
# text                        Non mi sembra sia stato buttato via nulla di q...
# textlen                                                                119981
# num_rep                                                                  4419
# anticipazione                                                               5
# causa                                                                      54
# commento                                                                  604
# conferma                                                                   86
# considerazione                                                             31
# contrapposizione                                                          176
# deresponsabilizzazione                                                     79
# descrizione                                                               415
# dichiarazione di intenti                                                   62
# generalizzazione                                                          154
# giudizio                                                                  303
# giustificazione                                                            54
# implicazione                                                               82
# non risposta                                                              164
# opinione                                                                  163
# possibilità                                                                68
# prescrizione                                                              239
# previsione                                                                132
# proposta                                                                   22
# ridimensionamento                                                          87
# sancire                                                                   595
# specificazione                                                            138
# valutazione                                                               235
# dtype: object

# %%
val.describe()
# Out:
#            textlen      num_rep  anticipazione        causa     commento  \
# count  2214.000000  2214.000000    2214.000000  2214.000000  2214.000000
# mean     52.681572     1.990063       0.001355     0.023487     0.267389
# std      74.083277     2.081678       0.036794     0.151478     0.442697
# min       1.000000     1.000000       0.000000     0.000000     0.000000
# 25%      21.000000     1.000000       0.000000     0.000000     0.000000
# 50%      30.000000     1.000000       0.000000     0.000000     0.000000
# 75%      46.000000     2.000000       0.000000     0.000000     1.000000
# max     511.000000    41.000000       1.000000     1.000000     1.000000
#
#           conferma  considerazione  contrapposizione  deresponsabilizzazione  \
# count  2214.000000     2214.000000       2214.000000             2214.000000
# mean      0.034779        0.013098          0.080849                0.033875
# std       0.183260        0.113722          0.272665                0.180949
# min       0.000000        0.000000          0.000000                0.000000
# 25%       0.000000        0.000000          0.000000                0.000000
# 50%       0.000000        0.000000          0.000000                0.000000
# 75%       0.000000        0.000000          0.000000                0.000000
# max       1.000000        1.000000          1.000000                1.000000
#
#        descrizione  dichiarazione di intenti  generalizzazione     giudizio  \
# count  2214.000000               2214.000000       2214.000000  2214.000000
# mean      0.181120                  0.027100          0.067751     0.142276
# std       0.385205                  0.162412          0.251374     0.349412
# min       0.000000                  0.000000          0.000000     0.000000
# 25%       0.000000                  0.000000          0.000000     0.000000
# 50%       0.000000                  0.000000          0.000000     0.000000
# 75%       0.000000                  0.000000          0.000000     0.000000
# max       1.000000                  1.000000          1.000000     1.000000
#
#        giustificazione  implicazione  non risposta     opinione  possibilità  \
# count      2214.000000   2214.000000   2214.000000  2214.000000  2214.000000
# mean          0.023939      0.037940      0.070461     0.071364     0.031617
# std           0.152892      0.191095      0.255980     0.257490     0.175018
# min           0.000000      0.000000      0.000000     0.000000     0.000000
# 25%           0.000000      0.000000      0.000000     0.000000     0.000000
# 50%           0.000000      0.000000      0.000000     0.000000     0.000000
# 75%           0.000000      0.000000      0.000000     0.000000     0.000000
# max           1.000000      1.000000      1.000000     1.000000     1.000000
#
#        prescrizione   previsione     proposta  ridimensionamento      sancire  \
# count   2214.000000  2214.000000  2214.000000        2214.000000  2214.000000
# mean       0.110659     0.059169     0.014453           0.048329     0.277326
# std        0.313781     0.235994     0.119378           0.214509     0.447780
# min        0.000000     0.000000     0.000000           0.000000     0.000000
# 25%        0.000000     0.000000     0.000000           0.000000     0.000000
# 50%        0.000000     0.000000     0.000000           0.000000     0.000000
# 75%        0.000000     0.000000     0.000000           0.000000     1.000000
# max        1.000000     1.000000     1.000000           1.000000     1.000000
#
#        specificazione  valutazione
# count     2214.000000  2214.000000
# mean         0.060976     0.117435
# std          0.239340     0.322010
# min          0.000000     0.000000
# 25%          0.000000     0.000000
# 50%          0.000000     0.000000
# 75%          0.000000     0.000000
# max          1.000000     1.000000

# %%
test_val.sum()
# Out:
# text                        Per favore, mettete qualche controllo in più n...
# textlen                                                                240026
# num_rep                                                                  8723
# anticipazione                                                              10
# causa                                                                     118
# commento                                                                 1187
# conferma                                                                  151
# considerazione                                                             66
# contrapposizione                                                          347
# deresponsabilizzazione                                                    164
# descrizione                                                               846
# dichiarazione di intenti                                                  115
# generalizzazione                                                          304
# giudizio                                                                  638
# giustificazione                                                           112
# implicazione                                                              159
# non risposta                                                              303
# opinione                                                                  324
# possibilità                                                               117
# prescrizione                                                              462
# previsione                                                                244
# proposta                                                                   54
# ridimensionamento                                                         204
# sancire                                                                  1216
# specificazione                                                            270
# valutazione                                                               470
# dtype: object

# %%
val.sum()
# Out:
# text                        - Zaia, manca il personale nelle case di ripos...
# textlen                                                                118959
# num_rep                                                                  4449
# anticipazione                                                               7
# causa                                                                      70
# commento                                                                  581
# conferma                                                                   80
# considerazione                                                             30
# contrapposizione                                                          193
# deresponsabilizzazione                                                     81
# descrizione                                                               410
# dichiarazione di intenti                                                   55
# generalizzazione                                                          155
# giudizio                                                                  319
# giustificazione                                                            57
# implicazione                                                               77
# non risposta                                                              153
# opinione                                                                  172
# possibilità                                                                53
# prescrizione                                                              232
# previsione                                                                122
# proposta                                                                   26
# ridimensionamento                                                         116
# sancire                                                                   621
# specificazione                                                            152
# valutazione                                                               236
# dtype: object

# %%
train.head()
# Out:
#                                                 text  textlen  num_rep  \
# 0  Dunque vediamo se ho capito: Conte le canta a ...       47        6
# 2  Comunque, se tutti i giornalisti che oggi si s...       42        2
# 4  Non era mai successo nella lunga storia del Pi...      104        7
# 5  Via via che si aggrava la crisi prodotta dalla...      186       12
# 6  Vi do la buonanotte con un pensiero profondo\r...       30        1
#
#    anticipazione  causa  commento  conferma  considerazione  contrapposizione  \
# 0              0      0         1         0               0                 0
# 2              0      0         1         0               0                 0
# 4              0      1         0         1               0                 1
# 5              0      1         1         0               0                 0
# 6              0      0         0         0               0                 0
#
#    deresponsabilizzazione  descrizione  dichiarazione di intenti  \
# 0                       0            0                         1
# 2                       0            0                         0
# 4                       0            0                         1
# 5                       0            0                         0
# 6                       0            0                         0
#
#    generalizzazione  giudizio  giustificazione  implicazione  non risposta  \
# 0                 0         1                1             0             0
# 2                 0         0                0             0             0
# 4                 0         0                0             0             0
# 5                 0         1                0             0             0
# 6                 0         0                0             0             1
#
#    opinione  possibilità  prescrizione  previsione  proposta  \
# 0         0            0             0           0         0
# 2         0            1             0           0         0
# 4         0            0             0           0         0
# 5         0            0             0           0         0
# 6         0            0             0           0         0
#
#    ridimensionamento  sancire  specificazione  valutazione
# 0                  0        1               0            0
# 2                  0        0               0            0
# 4                  0        1               1            0
# 5                  1        1               0            0
# 6                  0        0               0            0

# %%
train.to_csv("mult_train.csv", index=False)
val.to_csv("mult_val.csv", index=False)
test.to_csv("mult_test.csv", index=False)

# %%
df1.to_csv("multi_rep.csv", index=False)

# %%
import numpy as np
df3 = train.drop(['text', 'textlen', 'num_rep'], axis=1)
np.array((1 - df3.mean()) /  df3.mean())
# Out:
# array([514.25      ,  39.41176471,   2.79558011,  28.11016949,
#         65.91558442,  11.50606796,  24.44444444,   4.18360161,
#         36.20216606,  16.23244147,   5.80647292,  39.25390625,
#         27.7849162 ,  13.91316932,  13.3125    ,  32.45779221,
#          8.39380128,  16.890625  ,  68.62837838,  20.60377358,
#          2.5682133 ,  16.49575552,   8.56824513])

# %%
(len(df3) - df3.sum()) / df3.sum()
# Out:
# anticipazione               514.250000
# causa                        39.411765
# commento                      2.795580
# conferma                     28.110169
# considerazione               65.915584
# contrapposizione             11.506068
# deresponsabilizzazione       24.444444
# descrizione                   4.183602
# dichiarazione di intenti     36.202166
# generalizzazione             16.232441
# giudizio                      5.806473
# giustificazione              39.253906
# implicazione                 27.784916
# non risposta                 13.913169
# opinione                     13.312500
# possibilità                  32.457792
# prescrizione                  8.393801
# previsione                   16.890625
# proposta                     68.628378
# ridimensionamento            20.603774
# sancire                       2.568213
# specificazione               16.495756
# valutazione                   8.568245
# dtype: float64
