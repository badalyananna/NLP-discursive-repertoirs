# %%
import pandas as pd
df = pd.read_csv("hyperion_train.csv", sep=",")

# %%
from hyperion_dataset import HyperionDataset

# %%
df
# Out:
#       Domanda                                              Testo  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# ...       ...                                                ...
# 28058     NaN                                                NaN
# 28059     NaN  Nico Niero per la prima volta ritengo doveroso...
# 28060     NaN                                                NaN
# 28061     NaN                                                NaN
# 28062     NaN                                                NaN
#
#                                                 Stralcio     Repertorio  \
# 0      CՏ, innanzitutto, un orizzonte di breve perio...  anticipazione
# ...

# %%
df
# Out:
#       Domanda                                              Testo  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# ...       ...                                                ...
# 28058     NaN                                                NaN
# 28059     NaN  Nico Niero per la prima volta ritengo doveroso...
# 28060     NaN                                                NaN
# 28061     NaN                                                NaN
# 28062     NaN                                                NaN
#
#                                                 Stralcio     Repertorio  \
# 0      CՏ, innanzitutto, un orizzonte di breve perio...  anticipazione
# ...

# %%
test_data = HyperionDataset(df, 'bert')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18316/529068855.py in <module>
# ----> 1 test_data = HyperionDataset(df, 'bert')
#
# ~\Documents\Personal_files\Uni_DS\projects\Bert_16_class\hyperion_dataset.py in __init__(self, df, tokenizer_name)
#      43         df = filter_empty_labels(df)
#      44         #df = twitter_preprocess(df)
# ---> 45         df = to_lower_case(df)
#      46         uniform_labels(df)
#      47         tokenizer = AutoTokenizer.from_pretrained(tokenizer_name)
#
# ~\Documents\Personal_files\Uni_DS\projects\Bert_16_class\hyperion_dataset.py in to_lower_case(df)
#      96 #Convert to lower case
#      97 def to_lower_case(df):
# ---> 98     return df.applymap(str.lower)
#      99
#     100
#
# ...
